# %%
from numpy import *
from matplotlib import *
from pylab import *
import pandas as pd
from tqdm import tqdm_notebook as tqdm
#import matplotlib.pyplot as plt

# %%
df = pd.read_csv("real1d-dyn.txt" , sep='\\s+', header=None)

# %%
df.columns = ['x', 't', 'z']

# %%
figure(figsize=(8, 6))
scatter1=scatter(df['x'], df['t'], c=df['z'], cmap='viridis')
colorbar(scatter1, label='Z Value')
xlabel('x ')
ylabel('t ')
savefig("density_10b.png")
plt.show()
